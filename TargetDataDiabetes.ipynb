# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.7 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for diabetes mellitus
target = new_client.target
target_query = target.search('diabetes')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references           organism  \
# 0                []       Homo sapiens
# 1                []       Homo sapiens
# 2                []       Mus musculus
# 3                []  Rattus norvegicus
# 4                []   Canis familiaris
# 5                []       Homo sapiens
# 6                []       Homo sapiens
# 7                []       Homo sapiens
# 8                []       Homo sapiens
# 9                []       Homo sapiens
# 10               []       Homo sapiens
# 11               []       Homo sapiens
# 12               []       Homo sapiens
#
#                                             pref_name  score  \
# 0                           Islet amyloid polypeptide   19.0
# 1    Peroxisome proliferator-activated receptor gamma    9.0
# 2    Peroxisome proliferator-activated receptor gamma    9.0
# 3    Peroxisome proliferator-activated receptor gamma    9.0
# 4    Peroxisome proliferator-activated receptor gamma    9.0
# ...

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL235'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       105368                  []
# 1        None             None       108760                  []
# 2        None             None       108770                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL759452  In vitro binding affinity against human peroxi...
# 1    CHEMBL759452  In vitro binding affinity against human peroxi...
# 2    CHEMBL759452  In vitro binding affinity against human peroxi...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism                                  target_pref_name  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# -rw------- 1 root root 1534611 Dec 16 19:44 '/content/gdrive/My Drive/Colab Notebooks/data'

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2256  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 2257  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 2258                                               None             None
# 2259                                               None             None
# 2260                                               None             None
#
#       activity_id                                activity_properties  \
# ...

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 15000:
    bioactivity_class.append("inactive")
  elif float(i) <= 3000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL327767  CCCc1cc(Oc2ccc(CC(C)C)cc2)ccc1OCCCOc1cccc(C2SC...
# 1           CHEMBL94496  CCCc1cc(Oc2ccc(C(C)C)cc2)ccc1OCCCOc1cccc(C2SC(...
# 2          CHEMBL420441  CCCc1cc(Oc2ccc(Cl)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 3             CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 4          CHEMBL330191  CCCc1cc(Oc2ccccc2)ccc1OCCCCOc1cccc(C2SC(=O)NC2...
# ...                 ...                                                ...
# 2159      CHEMBL1236924  O=S(=O)(Nc1cc(Cl)c(Oc2cnc3ccccc3c2)c(Cl)c1)c1c...
# 2160      CHEMBL3585580  COc1ccc(Oc2cc(N(C)CCOc3ccc(CC4SC(=O)NC4=O)cc3)...
# 2161       CHEMBL247920  CCc1c(-c2ccccc2)c(-c2ccccc2)nn1-c1ccccc1-c1ccc...
# 2162      CHEMBL5420532  O=C(O)Cc1ccc(-c2ccc(OCc3c(-c4c(Cl)cccc4Cl)noc3...
# 2163      CHEMBL5396467  O=C(O)C1(c2cccc(-c3ccc(OCc4c(-c5c(Cl)cccc5Cl)n...
#
#      bioactivity_class standard_value
# ...

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3['bioactivity_class'] = bioactivity_class
df3
# Out:
# <ipython-input-23-a96ce00ac998>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['bioactivity_class'] = bioactivity_class
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL327767  CCCc1cc(Oc2ccc(CC(C)C)cc2)ccc1OCCCOc1cccc(C2SC...
# 1           CHEMBL94496  CCCc1cc(Oc2ccc(C(C)C)cc2)ccc1OCCCOc1cccc(C2SC(...
# 2          CHEMBL420441  CCCc1cc(Oc2ccc(Cl)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 3             CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 4          CHEMBL330191  CCCc1cc(Oc2ccccc2)ccc1OCCCCOc1cccc(C2SC(=O)NC2...
# ...                 ...                                                ...
# 2256      CHEMBL1236924  O=S(=O)(Nc1cc(Cl)c(Oc2cnc3ccccc3c2)c(Cl)c1)c1c...
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL327767  CCCc1cc(Oc2ccc(CC(C)C)cc2)ccc1OCCCOc1cccc(C2SC...
# 1           CHEMBL94496  CCCc1cc(Oc2ccc(C(C)C)cc2)ccc1OCCCOc1cccc(C2SC(...
# 2          CHEMBL420441  CCCc1cc(Oc2ccc(Cl)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 3             CHEMBL121            CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1ccccn1
# 4          CHEMBL330191  CCCc1cc(Oc2ccccc2)ccc1OCCCCOc1cccc(C2SC(=O)NC2...
# ...                 ...                                                ...
# 2088                NaN                                                NaN
# 2095                NaN                                                NaN
# 2101                NaN                                                NaN
# 2103                NaN                                                NaN
# 2106                NaN                                                NaN
#
#      standard_value bioactivity_class         0
# ...

# %%
df3.to_csv('bioactivity_preprocessed_data_updated.csv', index=False)

# %%
! ls -l
# Out:
# total 1696
# -rw-r--r-- 1 root root 1534611 Dec 16 19:43 bioactivity_data.csv
# -rw-r--r-- 1 root root  191985 Dec 16 19:44 bioactivity_preprocessed_data_updated.csv
# drwx------ 7 root root    4096 Dec 16 19:44 gdrive
# drwxr-xr-x 1 root root    4096 Dec 12 14:22 sample_data

# %%
! cp bioactivity_preprocessed_data_updated.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data'
